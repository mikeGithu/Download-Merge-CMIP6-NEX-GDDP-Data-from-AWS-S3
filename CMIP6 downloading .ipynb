# %%
import os
import xarray as xr 
import s3fs
import netCDF4 as nc

# %%
# Configuration
##bucket_path = "s3://nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr" 
##s3://nex-gddp-cmip6/NEX-GDDP-CMIP6/<MPI-ESM1-2-HR>/<experiment>/<variable>/

bucket = "nex-gddp-cmip6"    
output_dir = "D:/PAU document/Thesis/Analysis/CMIP6 data/MPI-ESM1-2-HR/Historical/"
model = "MPI-ESM1-2-HR"
senario = "historical"
experiment = "r1i1p1f1"
variable = "pr"  # or tasmin, pr, etc.
start_year = 1983
end_year = 2014
os.makedirs(output_dir, exist_ok = True)

# %%
# Connect to public S3 bucket
fs = s3fs.S3FileSystem(anon=True)
print(fs)
# Out:
# <s3fs.core.S3FileSystem object at 0x000001C71F35CE10>

# %%
# List all files in the directory
prefix = f"NEX-GDDP-CMIP6/{model}/{senario}/{variable}/"
##files = fs.ls(bucket_path + prefix)
#files = fs.ls(f"{bucket}/{prefix}")

# %%
fs.ls(f"{bucket}/NEX-GDDP-CMIP6/{model}/")
# Out:
# ['nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical',
#  'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/ssp126',
#  'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/ssp245',
#  'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/ssp370',
#  'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/ssp585']

# %%
files = fs.ls(f"{bucket}/NEX-GDDP-CMIP6/{model}/historical/r1i1p1f1/pr/")

# %%
print(files)
# Out:
# ['nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1950.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1950_v1.1.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1951.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1951_v1.1.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1952.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1952_v1.1.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1953.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1953_v1.1.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1954.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1954_v1.1.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1955.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1955_v1.1.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1956.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1956_v1.1.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1957.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1957_v1.1.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1958.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1958_v1.1.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1959.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1959_v1.1.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1960.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1960_v1.1.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1961.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1961_v1.1.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1962.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1962_v1.1.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1963.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1963_v1.1.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1964.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1964_v1.1.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1965.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1965_v1.1.nc', 'nex-gddp-cmip6 ...

# %%
# Filter by year range
filtered_files = [f for f in files if any(f"{year}.nc" in f for year in range(start_year, end_year + 1))]

# %%
print(filtered_files)
# Out:
# ['nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1983.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1984.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1985.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1986.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1987.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1988.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1989.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1990.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1991.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1992.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1993.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1994.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1995.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1996.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1997.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1998.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_1999.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_2000.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_2001.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_2002.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_2003.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_2004.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_2005.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_2006.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_2007.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_2008.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_2009.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_2010.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_2011.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_2012.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_2013.nc', 'nex-gddp-cmip6/NEX-GDDP-CMIP6/MPI-ESM1-2-HR/historical/r1i1p1f1/pr/pr_day_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_2014.nc']

# %%
# Download files locally
local_files = []
for s3_file in filtered_files:
    filename = os.path.basename(s3_file)
    local_path = os.path.join(output_dir, filename)
    if not os.path.exists(local_path):
        print(f"Downloading {filename}...")
        fs.get(s3_file, local_path)
    else:
        print(f"File {filename} already exists.")
    local_files.append(local_path)

# %%
# Merge using xarray
print("Merging files...")
datasets = [xr.open_dataset(f) for f in local_files]
combined = xr.concat(datasets, dim="time")
# Out:
# Merging files...
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\xarray\structure\concat.py:254, in concat(objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs, create_index_for_new_dim)
#     253 try:
# --> 254     first_obj, objs = utils.peek_at(objs)
#     255 except StopIteration as err:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xarray\core\utils.py:250, in peek_at(iterable)
#     249 gen = iter(iterable)
# --> 250 peek = next(gen)
#     251 return peek, itertools.chain([peek], gen)
#
# StopIteration:
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 4
#       2 print("Merging files...")
#       3 datasets = [xr.open_dataset(f) for f in local_files]
# ----> 4 combined = xr.concat(datasets, dim="time")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xarray\structure\concat.py:256, in concat(objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs, create_index_for_new_dim)
#     254     first_obj, objs = utils.peek_at(objs)
#     255 except StopIteration as err:
# --> 256     raise ValueError("must supply at least one object to concatenate") from err
#     258 if compat not in set(_VALID_COMPAT) - {"minimal"}:
#     259     raise ValueError(
#     260         f"compat={compat!r} invalid: must be 'broadcast_equals', 'equals', 'identical', 'no_conflicts' or 'override'"
#     261     )
#
# ValueError: must supply at least one object to concatenate

# %%
# Save merged dataset
merged_path = os.path.join(output_dir, f"{model}_{experiment}_{variable}_{start_year}-{end_year}.nc")
combined.to_netcdf(merged_path)
print(f"Merged file saved to: {merged_path}")
